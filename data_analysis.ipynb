# %% [markdown]
# #### Load libraries

# %%
#Ipython settings
# %pylab inline
# %load_ext autoreload
# %autoreload 2

#Python libraries
import os
import re

# Python packages
import pandas as pd
import seaborn as sns

# User modules
import helpers

# Figure styles
sns.set_context('notebook')
sns.set_style("white")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### Set data paths

# %%
data_path = "/home/kunal/tscc_projects/lasken/data2/"
bam_dir = os.path.join(data_path, 'bam')
out_dir = os.path.join(data_path, 'out')
rsem_dir = os.path.join(data_path,'genes')
path_to_samtools = '/path/to/samtools'
path_to_genebody_coverage = '/path/to/rnaseqc/geneBody_coverage.py'
path_to_gtf_to_bed = '/path/to/gtf2bed.pl'

# %% [markdown]
# #### Set Sample Map

# %%
sample_ids = """1E1HCNP111314
1F1HCNP111314
1G1HCNP111314
1H1HCNP111314
2A1HCNPN111314
2B1HCNPN111314
2C1HCNPN111314
2D1HCNPN111314
2G1HCNPN111314
2H1HCNPN111314
3AHCN100pg111314
3BHCN10pg111314
3DHCN100pg111314
3EHCN10pg111314""".split('\n')

sample_names = """Non-neuronal nucleus-1
Non-neuronal nucleus-2
Non-neuronal nucleus-3
Non-neuronal nucleus-4
Neuronal nucleus-1
Neuronal nucleus-2
Neuronal nucleus-3
Neuronal nucleus-4
Neuronal nucleus-5
Neuronal nucleus-6
Total RNA-100pg-1
Total RNA-10pg-1
Total RNA-100pg-2
Total RNA-10pg-2""".split('\n')

sample_map = dict((sample[0], sample[1])
                for sample in zip(sample_ids, sample_names))

# %% [markdown]
# ### RNASeq Analysis: Overall read statistics from aligned bam files

# %% [markdown]
# #### Calculating and plotting overall read statistics

# %%
for fn in os.listdir(bam_dir):
    if fn.endswith('.genome.sorted.bam'):
        out_file = os.path.join(out_dir, 
                                fn.replace('.bam','.idxstats'))
        in_file = os.path.join(bam_dir, fn)
        samtools_cmd = "%s idxstats %s > %s" % \
        (path_to_samtools, in_file, out_file)
        print "Running samtools idxstats for file: %s" % fn
        #!$samtools_cmd
# Out:
# Running samtools idxstats for file: 3EHCN10pg111314.genome.sorted.bam
# Running samtools idxstats for file: 7A8HCNPD2102414.genome.sorted.bam
# Running samtools idxstats for file: 2C1HCNPN111314.genome.sorted.bam
# Running samtools idxstats for file: 2H1HCNPN111314.genome.sorted.bam
# Running samtools idxstats for file: 7F96HCNPD2102414.genome.sorted.bam
# Running samtools idxstats for file: 2D1HCNPN111314.genome.sorted.bam
# Running samtools idxstats for file: 7D24HCNPD2102414.genome.sorted.bam
# Running samtools idxstats for file: 2C1HCNPD2102414.genome.sorted.bam
# Running samtools idxstats for file: 2B1HCNPN111314.genome.sorted.bam
# Running samtools idxstats for file: 3DHCN100pg111314.genome.sorted.bam
# Running samtools idxstats for file: 1G1HCNP111314.genome.sorted.bam
# Running samtools idxstats for file: 7E48HCNPD2102414.genome.sorted.bam
# Running samtools idxstats for file: 3BHCN10pg111314.genome.sorted.bam
# Running samtools idxstats for file: 2G1HCNPN111314.genome.sorted.bam
# Running samtools idxstats for file: 3F1HCNPD3102414.genome.sorted.bam
# Running samtools idxstats for file: 1H1HCNP111314.genome.sorted.bam
# Running samtools idxstats for file: 3B1HCNPD3102414.genome.sorted.bam
# Running samtools idxstats for file: 2A1HCNPN111314.genome.sorted.bam
# Running samtools idxstats for file: 1F1HCNP111314.genome.sorted.bam
# Running samtools idxstats for file: 1E1HCNP111314.genome.sorted.bam
# Running samtools idxstats for file: 1A1HCNPD1102414.genome.sorted.bam
# Running samtools idxstats for file: 3AHCN100pg111314.genome.sorted.bam
# Running samtools idxstats for file: 1E1HCNPD1102414.genome.sorted.bam

# %% [markdown]
# #### Generate plot detailing mapping statistics

# %%
mapped_df = helpers.load_mapped_data(out_dir, sample_map).sort()
ax = mapped_df.plot(kind='barh', stacked=True)
ax.set_xlabel('Number of Reads');

# %% [markdown]
# ### RNASeq Analysis:  Exploration of biological and technical variation by stratifying gene expression based on expression in bulk RNA

# %% [markdown]
# #### Load TPM data

# %%
tpm_df = helpers.filter_df(helpers.load_tpms(rsem_dir, sample_map), 
                            genes_only=True,
                            expressed_in_multiple=False)

# %% [markdown]
# #### Bin bulk RNA expression genes into low, mid, and high

# %%
control = 'Total RNA-100pg-2' # Set control sample name
low, mid, high = helpers.get_low_mid_high_genes(tpm_df[control])
control_expressed = tpm_df[tpm_df[control] > 0][[control]]

# %%
df = pd.concat([low.describe(), mid.describe(), high.describe()], axis=1)
df.columns = ['Low', 'Mid', 'High']
df
# Out:
#                Low          Mid           High
# count  4940.000000  4933.000000    4941.000000
# mean      2.846366    11.975206     185.200385
# std       1.639044     4.314163    2590.545279
# min       0.010000     6.040000      21.480000
# 25%       1.410000     8.190000      31.250000
# 50%       2.640000    11.150000      48.960000
# 75%       4.222500    15.310000      96.680000
# max       6.030000    21.470000  174086.370000

# %% [markdown]
# #### Calculate fraction of genes represented in each sample

# %%
expressed_df = helpers.calculate_relative_expression(tpm_df, low, mid, high)

# %%
expressed_df
# Out:
#                         High   Low   Mid  Novel
# Neuronal nucleus-1      1993   413   772    219
# Neuronal nucleus-2      2617   767  1263    489
# Neuronal nucleus-3      2937  1000  1526    758
# Neuronal nucleus-4      1813   463   761    304
# Neuronal nucleus-5      2503   882  1311    652
# Neuronal nucleus-6      1902   530   923    335
# Non-neuronal nucleus-1   732   224   305    190
# Non-neuronal nucleus-2   606   150   224    122
# Non-neuronal nucleus-3   754   211   277    146
# Non-neuronal nucleus-4  2153   468   928    339
# Total RNA-100pg-1       4443  1873  2926   1113
# Total RNA-100pg-2       4941  4940  4933      0
# Total RNA-10pg-1        3811  1141  1922    587
# Total RNA-10pg-2        4152  1602  2514    922

# %% [markdown]
# #### For each sample, plot percentage of bulk RNA represented

# %%
cols = ['Low','Mid','High']
control_values = expressed_df[cols].ix[control]
fraction_df = expressed_df[cols].astype(float)/control_values
ax = fraction_df.plot(kind='barh')
ax.set_title('Fraction of %s Genes Expressed' % control);
ax.set_xlabel('Fraction of Genes Expressed');

# %% [markdown]
# #### For each sample, calculate composition compared to bulk RNA

# %%
composition_df = expressed_df.apply(lambda x: x.astype(float)/x.sum(),
                                    axis=1)
cols = ['Low', 'Mid', 'High', 'Novel']
ax = composition_df[cols].plot(kind='barh')
ax.set_title('Composition of Genes Expressed \nRelative to Expression in %s' % control,
             loc='left')
ax.set_xlabel('Fraction of Genes Expressed');

# %% [markdown]
# #### Plot the correlation in gene expression based on different sets of genes

# %%
for genes, gene_type in zip([low, mid, high], ['Low', 'Mid', 'High']):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    ax = sns.corrplot(tpm_df.ix[genes].sort(axis=1), method='spearman', 
                          ax=ax, diag_names=False, cmap_range=(0, 1), cbar=True)       
    ax.set_title('Correlation Stratified by %s Expression in %s' % (gene_type, control))
    sns.despine()

# %% [markdown]
# ### RNASeq Analysis: Quality control based on 3’ bias in cDNA synthesis and sequencing depths across gene body

# %% [markdown]
# #### Create bed file for highly expressed genes in bulk sample

# %%
gtf_file = os.path.join(data_path, 
                        'reference',
                        'GRCh37_ERCC_GFP_RNASpikes.gtf')
high_gtf = gtf_file.replace('.gtf','.high_expressed.gtf')
print "Subsetting %s to only highly expressed genes as %s" % (gtf_file, high_gtf)

helpers.subset_gtf_by_genes(high_gtf, gtf_file, list(high.index))
high_bed = high_gtf.replace('.gtf','.bed')
print "Converting %s to %s" % (high_gtf, high_bed)
# !perl gtf2bed.pl $high_gtf > $high_bed
# Out:
# Subsetting /home/kunal/tscc_projects/lasken/data2/reference/GRCh37_ERCC_GFP_RNASpikes.gtf to only highly expressed genes as /home/kunal/tscc_projects/lasken/data2/reference/GRCh37_ERCC_GFP_RNASpikes.high_expressed.gtf
# Converting /home/kunal/tscc_projects/lasken/data2/reference/GRCh37_ERCC_GFP_RNASpikes.high_expressed.gtf to /home/kunal/tscc_projects/lasken/data2/reference/GRCh37_ERCC_GFP_RNASpikes.high_expressed.bed

# %% [markdown]
# #### Run RNA-SeqC Gene Body Coverage for each sample

# %%
rnaseqc_prefix = os.path.join(out_dir, "rnaseqc_high_coverage_control")
sample_files = [os.path.join(bam_dir, fn) for fn in os.listdir(bam_dir)
                if fn.endswith('.genome.sorted.bam')]
in_files = ", ".join(sample_files)
rnaseq_c_cmd = "%s -i %s --refgene %s --out_prefix %s" % \
            (path_to_genebody_coverage, in_files, high_bed, rnaseqc_prefix)
fns = ", ".join([os.path.basename(fn) for fn in sample_files])
print "Running gene body coverage for sample files: %s" % fns 
#!rnaseq_c_cmd
# Out:
# Running gene body coverage for sample files: 3EHCN10pg111314.genome.sorted.bam, 7A8HCNPD2102414.genome.sorted.bam, 2C1HCNPN111314.genome.sorted.bam, 2H1HCNPN111314.genome.sorted.bam, 7F96HCNPD2102414.genome.sorted.bam, 2D1HCNPN111314.genome.sorted.bam, 7D24HCNPD2102414.genome.sorted.bam, 2C1HCNPD2102414.genome.sorted.bam, 2B1HCNPN111314.genome.sorted.bam, 3DHCN100pg111314.genome.sorted.bam, 1G1HCNP111314.genome.sorted.bam, 7E48HCNPD2102414.genome.sorted.bam, 3BHCN10pg111314.genome.sorted.bam, 2G1HCNPN111314.genome.sorted.bam, 3F1HCNPD3102414.genome.sorted.bam, 1H1HCNP111314.genome.sorted.bam, 3B1HCNPD3102414.genome.sorted.bam, 2A1HCNPN111314.genome.sorted.bam, 1F1HCNP111314.genome.sorted.bam, 1E1HCNP111314.genome.sorted.bam, 1A1HCNPD1102414.genome.sorted.bam, 3AHCN100pg111314.genome.sorted.bam, 1E1HCNPD1102414.genome.sorted.bam

# %% [markdown]
# #### Plot the gene body coverage across all samples

# %%
rnaseqc_file = rnaseqc_prefix+'.geneBodyCoverage.txt'
normalized_df, coverage_df = helpers.load_gene_body_coverage(rnaseqc_file, sample_map)
ax = normalized_df.plot()
ax.set_xlabel("Gene Body (5' -> 3')")
ax.set_ylabel("Relative Coverage")

# %% [markdown]
# ### RNASeq Analysis: Quality control based on coverage across exons and introns

# %% [markdown]
# #### Align reads using TopHat

# %% [raw]
# #An example TopHat command. Although it is assumed that the reader is familiar with the software.
# #One can download the reference files from http://ccb.jhu.edu/software/tophat/igenomes.shtml
# export BOWTIE_INDEXES=/path/to/bowtie-reference
# tophat GRCh37 input.sample.R1.fastq input.sample.R2.fastq
# #Also, we also recommend setting up the bcbio-nextgene RNA-Seq pipeline. Do note that if you select this option, you will have to add the SmartSeq2 adapter sequence to relevant files.

# %% [markdown]
# #### Load into IGV to manually inspect

# %% [raw]
# Use IGV (http://www.broadinstitute.org/igv/) to view the bam file.

# %% [markdown]
# #### (Optional) Create intron and exon bed files from provided gtf

# %%
intronic_bed = os.path.join(data_path,
                            'reference', 
                            'GRCh37_ERCC_GFP_RNASpikes.gtf.introns.bed')
exonic_bed = os.path.join(data_path,
                          'reference',
                          'GRCh37_ERCC_GFP_RNASpikes.gtf.exons.bed')

# %%
# Note: The following graphic presented on http://davetang.org/muse/2013/01/18/defining-genomic-regions/ (credit 
# to Dave Tang) shows how we define our intronic regions.
from IPython.display import Image
Image("http://i0.wp.com/davetang.org/muse/wp-content/uploads/2013/01/bedtools.png", 
      width="570", height="596")

# %%
# !sh create_intron_exon_beds.sh $gtf_file $exonic_bed $intronic_bed

# %% [markdown]
# #### (Optional) Find coverage overlaps with introns and exons

# %%
sample_tophat_bam = os.path.join(data_path, 'tophat', '2B1HCNPN111314-ready.bam')
intronic_out = sample_tophat_bam.replace('.bam','.intronic_coverage')
intronic_cmd = "bedtools bamtobed -splitD -i %s | awk \'BEGIN{OFS=\"\\t\"}$1=\"chr\"$1\' | bedtools coverage -a - -b %s \
    > %s" % (sample_tophat_bam, intronic_bed, intronic_out)
print "Creating intronic coverage file"
print intronic_cmd
#!$intronic_cmd
print

exonic_out = sample_tophat_bam.replace('.bam','.exonic_coverage')
exonic_cmd = "bedtools bamtobed -splitD -i %s | awk \'BEGIN{OFS=\"\\t\"}$1=\"chr\"$1\' | bedtools coverage -a - -b %s \
    > %s" % (sample_tophat_bam, exonic_bed, exonic_out)
print "Creating exonic coverage file"
print exonic_cmd
#!$exonic_cmd
print
# Out:
# Creating intronic coverage file
# bedtools bamtobed -splitD -i /home/kunal/tscc_projects/lasken/data2/tophat/2B1HCNPN111314-ready.bam | awk 'BEGIN{OFS="\t"}$1="chr"$1' | bedtools coverage -a - -b /home/kunal/tscc_projects/lasken/data2/reference/GRCh37_ERCC_GFP_RNASpikes.gtf.introns.bed     > /home/kunal/tscc_projects/lasken/data2/tophat/2B1HCNPN111314-ready.intronic_coverage
#
# Creating exonic coverage file
# bedtools bamtobed -splitD -i /home/kunal/tscc_projects/lasken/data2/tophat/2B1HCNPN111314-ready.bam | awk 'BEGIN{OFS="\t"}$1="chr"$1' | bedtools coverage -a - -b /home/kunal/tscc_projects/lasken/data2/reference/GRCh37_ERCC_GFP_RNASpikes.gtf.exons.bed     > /home/kunal/tscc_projects/lasken/data2/tophat/2B1HCNPN111314-ready.exonic_coverage

# %% [markdown]
# #### (Optional) Load bedtools coverage files for exons and introns

# %%
intronic_df = helpers.load_bedtools_coverage(intronic_out,
                                          min_reads=1,
                                          min_length=100)
exonic_df = helpers.load_bedtools_coverage(exonic_out, 1, 100)

# %% [markdown]
# #### (Optional) Plot exonic vs intronic coverage plots

# %%
fig = helpers.plot_bedtools_coverage(intronic_df, exonic_df)

# %% [markdown]
# #### Create TPM aggregated output file

# %%
tpm_file = os.path.join(out_dir, 'expression_tpm.tsv')
tpm_df.to_csv(tpm_file, sep='\t', header=True, index=True)
